# %% [markdown]
# Файл `Fishing.csv` содержит результаты опроса о рыбалке: респонденты, заполняя опросник, подробно описывали свою недавнюю рыбалку.
#
# **Описание переменных в датафрейме:**
#
#
# * `mode`: выбранный тип рыбалки: на берегу (`beach`), на пирсе (`pier`), в своей лодке (`boat`) и в арендованной лодке (`charter`);
#
# * `price`: стоимость выбранного типа рыбалки;
#
# * `catch`: коэффициент улова при выбранном типе рыбалки;
#
# * `pbeach`: стоимость рыбалки на берегу;
#
# * `ppier`: стоимость рыбалки на пирсе;
#
# * `pboat`: стоимость рыбалки на своей лодке;
#
# * `pcharter`: стоимость рыбалки на арендованной лодке;
#
# * `cbeach`: коэффициент улова на рыбалке на берегу;
#
# * `cpier`: коэффициент улова на рыбалке на пирсе;
#
# * `cboat`: коэффициент улова на рыбалке на своей лодке;
#
# * `ccharter`: коэффициент улова на рыбалке на арендованной лодке;
#
# * `income`: доход в месяц.
#
# Подробнее об опросе и исследовании можно почитать в [статье](https://core.ac.uk/download/pdf/38934845.pdf) J.Herriges, C.Kling *"Nonlinear Income Effects in Random Utility Models"* (1999).

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('[DMC.RIP] Fishing.csv')
df = df.drop(['Unnamed: 0','Unnamed: 0.1'],axis = 1)
df.head(8)
# Out:
#       mode    price   catch   pbeach    ppier    pboat  pcharter  cbeach  \
# 0  charter  182.930  0.5391  157.930  157.930  157.930   182.930  0.0678
# 1  charter   34.534  0.4671   15.114   15.114   10.534    34.534  0.1049
# 2     boat   24.334  0.2413  161.874  161.874   24.334    59.334  0.5333
# 3     pier   15.134  0.0789   15.134   15.134   55.930    84.930  0.0678
# 4     boat   41.514  0.1082  106.930  106.930   41.514    71.014  0.0678
# 5  charter   63.934  0.3975  192.474  192.474   28.934    63.934  0.5333
# 6    beach   51.934  0.0678   51.934   51.934  191.930   220.930  0.0678
# 7  charter   56.714  0.0209   15.134   15.134   21.714    56.714  0.0678
#
#     cpier   cboat  ccharter     income
# 0  0.0503  0.2601    0.5391  7083.3317
# 1  0.0451  0.1574    0.4671  1249.9998
# 2  0.4522  0.2413    1.0266  3749.9999
# 3  0.0789  0.1643    0.5391  2083.3332
# 4  0.0503  0.1082    0.3240  4583.3320
# 5  0.4522  0.1665    0.3975  4583.3320
# 6  0.0789  0.1643    0.5391  8750.0010
# 7  0.0789  0.0102    0.0209  2083.3332

# %%
df.columns
# Out:
# Index(['mode', 'price', 'catch', 'pbeach', 'ppier', 'pboat', 'pcharter',
#        'cbeach', 'cpier', 'cboat', 'ccharter', 'income'],
#       dtype='object')

# %% [markdown]
# ### Задание 1
#
# Добавить, используя метод `.apply()`, столбец `log_income`, содержащий натуральный логарифм доходов респондентов.

# %%
df['log_income'] = df.price.apply(np.log)

# %%
df.head(3)
# Out:
#       mode    price   catch   pbeach    ppier    pboat  pcharter  cbeach  \
# 0  charter  182.930  0.5391  157.930  157.930  157.930   182.930  0.0678
# 1  charter   34.534  0.4671   15.114   15.114   10.534    34.534  0.1049
# 2     boat   24.334  0.2413  161.874  161.874   24.334    59.334  0.5333
#
#     cpier   cboat  ccharter     income  log_income
# 0  0.0503  0.2601    0.5391  7083.3317    5.209104
# 1  0.0451  0.1574    0.4671  1249.9998    3.541944
# 2  0.4522  0.2413    1.0266  3749.9999    3.191875

# %% [markdown]
# ### Задание 2
#
# Посчитать для каждого респондента абсолютное значение отклонения `price` от `pbeach`  и сохранить результат в столбец `pdiff`.
#
# ***Подсказка 1:*** для нахождения абсолютного значения числа используется функция `abs()`. Пример:
#
#     abs(-8)
#     8
#
# ***Подсказка 2:*** пример с lamda-функцией в первом уроке этого модуля.

# %%
df.head(1)
# Out:
#       mode   price   catch  pbeach   ppier   pboat  pcharter  cbeach   cpier  \
# 0  charter  182.93  0.5391  157.93  157.93  157.93    182.93  0.0678  0.0503
#
#     cboat  ccharter     income  log_income
# 0  0.2601    0.5391  7083.3317    5.209104

# %%
df['pdiff'] = abs(df['price'] - df['pbeach'])

# %%
df.head(5)
# Out:
#       mode    price   catch   pbeach    ppier    pboat  pcharter  cbeach  \
# 0  charter  182.930  0.5391  157.930  157.930  157.930   182.930  0.0678
# 1  charter   34.534  0.4671   15.114   15.114   10.534    34.534  0.1049
# 2     boat   24.334  0.2413  161.874  161.874   24.334    59.334  0.5333
# 3     pier   15.134  0.0789   15.134   15.134   55.930    84.930  0.0678
# 4     boat   41.514  0.1082  106.930  106.930   41.514    71.014  0.0678
#
#     cpier   cboat  ccharter     income  log_income    pdiff
# 0  0.0503  0.2601    0.5391  7083.3317    5.209104   25.000
# 1  0.0451  0.1574    0.4671  1249.9998    3.541944   19.420
# 2  0.4522  0.2413    1.0266  3749.9999    3.191875  137.540
# 3  0.0789  0.1643    0.5391  2083.3332    2.716944    0.000
# 4  0.0503  0.1082    0.3240  4583.3320    3.726031   65.416

# %% [markdown]
# ### Задание 3
#
# Сгруппировать наблюдения в таблице по признаку тип рыбалки (`mode`) и вывести для каждого типа среднюю цену (`price`), которую респонденты заплатили за рыбалку.

# %%
ex4 = df.groupby('mode').agg('mean')

# %%
ex4['price']
# Out:
# mode
# beach      35.699493
# boat       41.606813
# charter    75.096942
# pier       30.571326
# Name: price, dtype: float64

# %% [markdown]
# ### Задание 4
#
# Сгруппировать наблюдения в таблице по признаку тип рыбалки (`mode`) и вывести для каждого типа разницу между медианным и средним значением цены (`price`), которую респонденты заплатили за рыбалку.
#
# **Посказка:** можно написать свою lambda-функцию для подсчёта разницы между медианой и средним и применить её внутри метода для агрегирования. Внимание: название самостоятельно написанной функции будет уже вводиться без кавычек.

# %%
df_med4 = df.groupby('mode').agg('median')

# %%
df_mean4 = df.groupby('mode').agg('mean')

# %%
df_med4 - df_mean4
# Out:
#              price     catch     pbeach      ppier      pboat   pcharter  \
# mode
# beach   -16.391493 -0.025495 -16.391493 -16.391493 -19.733134 -20.138164
# boat    -17.004813 -0.121641 -36.887100 -36.887100 -17.004813 -16.714086
# charter -18.226942 -0.269900 -28.602350 -28.602350 -19.693757 -18.226942
# pier    -13.942326 -0.052735 -13.942326 -13.942326 -13.724079 -14.487348
#
#            cbeach     cpier     cboat  ccharter      income  log_income  \
# mode
# beach   -0.025495 -0.069201  0.007101  0.021491 -301.616831   -0.097528
# boat    -0.103387 -0.050865 -0.121641 -0.256417 -904.106643    0.014207
# charter  0.001792 -0.080634 -0.115863 -0.269900 -130.899620   -0.109214
# pier    -0.007744 -0.052735  0.014151  0.041020 -470.505523   -0.042671
#
#              pdiff
# mode
# beach     0.000000
# boat    -34.870746
# charter -29.355735
# pier      0.000000

# %%
ex5 = abs(df_med4 - df_mean4)

# %%
ex5
# Out:
#              price     catch     pbeach      ppier      pboat   pcharter  \
# mode
# beach    16.391493  0.025495  16.391493  16.391493  19.733134  20.138164
# boat     17.004813  0.121641  36.887100  36.887100  17.004813  16.714086
# charter  18.226942  0.269900  28.602350  28.602350  19.693757  18.226942
# pier     13.942326  0.052735  13.942326  13.942326  13.724079  14.487348
#
#            cbeach     cpier     cboat  ccharter      income  log_income  \
# mode
# beach    0.025495  0.069201  0.007101  0.021491  301.616831    0.097528
# boat     0.103387  0.050865  0.121641  0.256417  904.106643    0.014207
# charter  0.001792  0.080634  0.115863  0.269900  130.899620    0.109214
# pier     0.007744  0.052735  0.014151  0.041020  470.505523    0.042671
#
#              pdiff
# mode
# beach     0.000000
# boat     34.870746
# charter  29.355735
# pier      0.000000

# %%
import statistics

# %%
my_list = [20, 25, 27, 2000, 56, 45, 17, 46, 35, 37,-3000,5000]

# %%
sorted(my_list)
# Out:
# [-3000, 17, 20, 25, 27, 35, 37, 45, 46, 56, 2000, 5000]

# %%
statistics.mean(my_list)
# Out:
# 7692639.076923077

# %%
statistics.median(my_list)
# Out:
# 36.0

# %% [markdown]
# ### Задание 5
#
# Сгруппировать наблюдения в таблице по признаку тип рыбалки (`mode`) и сохранить полученные датафреймы (один для каждого типа рыбалки) в отдельные csv-файлы. В итоге должно получиться четыре разных csv-файла.

# %%
pier = ex4.loc['pier']
pier.to_csv('pier.csv', index=False, header=None)

# %%
beach = ex4.loc['beach']
beach.to_csv('beach.csv', index=False, header=None)

# %%
boat = ex4.loc['boat']
boat.to_csv('boat.csv', index=False, header=None)

# %%
charter = ex4.loc['charter']
charter.to_csv('charter.csv', index=False, header=None)

# %% [markdown]
# ### Задание 6
#
# Отсортировать строки в датафрейме в соответствии со значениями `income` в порядке убывания таким образом, чтобы результаты сортировки сохранились в исходном датафрейме.

# %%
df.head(7)
# Out:
#       mode    price   catch   pbeach    ppier    pboat  pcharter  cbeach  \
# 0  charter  182.930  0.5391  157.930  157.930  157.930   182.930  0.0678
# 1  charter   34.534  0.4671   15.114   15.114   10.534    34.534  0.1049
# 2     boat   24.334  0.2413  161.874  161.874   24.334    59.334  0.5333
# 3     pier   15.134  0.0789   15.134   15.134   55.930    84.930  0.0678
# 4     boat   41.514  0.1082  106.930  106.930   41.514    71.014  0.0678
# 5  charter   63.934  0.3975  192.474  192.474   28.934    63.934  0.5333
# 6    beach   51.934  0.0678   51.934   51.934  191.930   220.930  0.0678
#
#     cpier   cboat  ccharter     income  log_income    pdiff
# 0  0.0503  0.2601    0.5391  7083.3317    5.209104   25.000
# 1  0.0451  0.1574    0.4671  1249.9998    3.541944   19.420
# 2  0.4522  0.2413    1.0266  3749.9999    3.191875  137.540
# 3  0.0789  0.1643    0.5391  2083.3332    2.716944    0.000
# 4  0.0503  0.1082    0.3240  4583.3320    3.726031   65.416
# 5  0.4522  0.1665    0.3975  4583.3320    4.157851  128.540
# 6  0.0789  0.1643    0.5391  8750.0010    3.949974    0.000

# %%
df_ex7 = df.sort_values(['income'], ascending = False)

# %%
df_ex7.head(8)
# Out:
#         mode    price   catch   pbeach    ppier    pboat  pcharter  cbeach  \
# 524  charter  240.586  0.5391  167.374  167.374  211.586   240.586  0.0678
# 130     boat   94.740  0.0108  205.270  205.270   94.740   129.740  0.0678
# 932     boat   37.896  0.0531  227.376  227.376   37.896    62.896  0.2537
# 36      pier  120.004  0.0789  120.004  120.004  252.640   281.640  0.0678
# 377     boat  328.432  0.0023  511.596  511.596  328.432   352.432  0.1049
# 832     boat   47.370  0.0732  555.808  555.808   47.370    76.870  0.0678
# 814     boat   47.370  0.0143  555.808  555.808   47.370    76.870  0.0678
# 556     boat   37.896  0.2413  581.072  581.072   37.896    72.896  0.5333
#
#       cpier   cboat  ccharter     income  log_income    pdiff
# 524  0.0789  0.1643    0.5391  12499.998    5.483078   73.212
# 130  0.0025  0.0108    0.2377  12499.998    4.551136  110.530
# 932  0.1498  0.0531    0.0052  12499.998    3.634846  189.480
# 36   0.0789  0.0014    0.0029  12499.998    4.787525    0.000
# 377  0.0451  0.0023    0.0046  12499.998    5.794330  183.164
# 832  0.0052  0.0732    0.1726  12499.998    3.857989  508.438
# 814  0.0503  0.0143    0.0289  12499.998    3.857989  508.438
# 556  0.4522  0.2413    1.0266  12499.998    3.634846  543.176

# %% [markdown]
# ### Задание 7
#
# Отсортировать строки в датафрейме в соответствии со значениями `price` и `income` в порядке возрастания. Можно ли сказать, что люди с более низким доходом и выбравшие более дешёвый тип рыбалки, в целом, предпочитают один тип рыбалки, а люди с более высоким доходом и более дорогой рыбалкой – другой? Ответ записать в виде текстовой ячейки или в виде комментария.

# %%
cols = list(df_ex8.columns.values)

# %%
cols
# Out:
# ['mode',
#  'price',
#  'catch',
#  'pbeach',
#  'ppier',
#  'pboat',
#  'pcharter',
#  'cbeach',
#  'cpier',
#  'cboat',
#  'ccharter',
#  'income',
#  'log_income',
#  'pdiff']

# %%
cols1 = ['mode',
 'price',
 'income',
 'catch',
 'pbeach',
 'ppier',
 'pboat',
 'pcharter',
 'cbeach',
 'cpier',
 'cboat',
 'ccharter',
 'log_income',
  'pdiff']

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df) # разовый показ

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 100)
pd.set_option('expand_frame_repr', True)

# %%
df_ex8
# Out:
#          mode    price       income   catch   pbeach    ppier    pboat  pcharter  cbeach   cpier  \
# 1013    beach    1.290    416.66668  0.5333    1.290    1.290   39.990    74.990  0.5333  0.4522
# 1105     pier    1.290    416.66668  0.4522    1.290    1.290   39.990    74.990  0.5333  0.4522
# 1157     pier    1.290    416.66668  0.4522    1.290    1.290   39.990    74.990  0.5333  0.4522
# 275      pier    2.290   1249.99980  0.0789    2.290    2.290    2.290    31.290  0.0678  0.0789
# 287      pier    2.290   1249.99980  0.0789    2.290    2.290    2.290    31.290  0.0678  0.0789
# ...       ...      ...          ...     ...      ...      ...      ...       ...     ...     ...
# 377      boat  328.432  12499.99800  0.0023  511.596  511.596  328.432   352.432  0.1049  0.0451
# 588   charter  330.072   6250.00130  0.0052  106.112  106.112  305.072   330.072  0.2537  0.1498
# 446   charter  335.314   8750.00100  1.0266  578.048  578.048  300.314   335.314  0.5333  0.4522
# 211   charter  387.208   7916.66630  2.3014  115.248  115.248  362.208   387.208  0.2537  0.1498
# 249      boat  666.110   8750.00100  0.0531  359.022  359.022  666.110   691.110  0.2537  0.1498
#
#        cboat  ccharter  log_income    pdiff
# 1013  0.2413    1.0266    0.254642    0.000
# 1105  0.0051    1.0266    0.254642    0.000
# 1157  0.1665    0.3975    0.254642    0.000
# 275   0.0971    0.1648    0.828552    0.000
# 287   0.1643    0.5391    0.828552    0.000
# ...      ...       ...         ...      ...
# 377   0.0023    0.0046    5.794330  183.164
# 588   0.0531    0.0052    5.799311  223.960
# 446   0.2413    1.0266    5.815067  242.734
# 211   0.6817    2.3014    5.958962  271.960
# 249   0.0531    0.0052    6.501455  307.088
#
# [1182 rows x 14 columns]

# %%
df_ex8.index
# Out:
# Int64Index([1013, 1105, 1157,  275,  287,  322,  323,  336,  339, 1012,
#             ...
#              357,  394,  400,  119,  343,  377,  588,  446,  211,  249],
#            dtype='int64', length=1182)

# %%
len(df_ex8)
# Out:
# 1182

# %%
df_ex8.index = list(range(1,1183))

# %%
df_ex8.head(15)
# Out:
#      mode  price      income   catch  pbeach   ppier   pboat  pcharter  cbeach   cpier   cboat  \
# 1   beach  1.290   416.66668  0.5333   1.290   1.290  39.990    74.990  0.5333  0.4522  0.2413
# 2    pier  1.290   416.66668  0.4522   1.290   1.290  39.990    74.990  0.5333  0.4522  0.0051
# 3    pier  1.290   416.66668  0.4522   1.290   1.290  39.990    74.990  0.5333  0.4522  0.1665
# 4    pier  2.290  1249.99980  0.0789   2.290   2.290   2.290    31.290  0.0678  0.0789  0.0971
# 5    pier  2.290  1249.99980  0.0789   2.290   2.290   2.290    31.290  0.0678  0.0789  0.1643
# 6    pier  2.290  1249.99980  0.0503   2.290   2.290   2.290    27.290  0.0678  0.0503  0.2601
# 7    pier  2.290  1249.99980  0.0503   2.290   2.290   2.290    27.290  0.0678  0.0503  0.2601
# 8   beach  2.290  1249.99980  0.0678   2.290   2.290   2.290    27.290  0.0678  0.0503  0.0276
# 9    boat  2.290  1249.99980  0.0276   2.290   2.290   2.290    27.290  0.0678  0.0503  0.0276
# 10  beach  2.290  1249.99980  0.5333   2.290   2.290  70.990   105.990  0.5333  0.4522  0.1665
# 11   pier  2.290  1249.99980  0.4522   2.290   2.290  70.990   105.990  0.5333  0.4522  0.2413
# 12   pier  2.290  1249.99980  0.4522   2.290   2.290  70.990   105.990  0.5333  0.4522  0.2413
# 13   pier  2.322   416.66668  0.4522   2.322   2.322  55.470    90.470  0.5333  0.4522  0.2413
# 14   pier  3.096   416.66668  0.4522   3.096   3.096  43.860    78.860  0.5333  0.4522  0.2413
# 15   boat  3.096   416.66668  0.0531  18.576  18.576   3.096    28.096  0.2537  0.1498  0.0531
#
#     ccharter  log_income  pdiff
# 1     1.0266    0.254642   0.00
# 2     1.0266    0.254642   0.00
# 3     0.3975    0.254642   0.00
# 4     0.1648    0.828552   0.00
# 5     0.5391    0.828552   0.00
# 6     0.5391    0.828552   0.00
# 7     0.5391    0.828552   0.00
# 8     0.0029    0.828552   0.00
# 9     0.0029    0.828552   0.00
# 10    0.3975    0.828552   0.00
# 11    1.0266    0.828552   0.00
# 12    1.0266    0.828552   0.00
# 13    1.0266    0.842429   0.00
# 14    1.0266    1.130111   0.00
# 15    0.0052    1.130111  15.48

# %% [markdown]
# ### Задание 8
#
# Любым известным способом проверить, есть ли в датафрейме пропущенные значения. Если есть, удалить строки с пропущенными значениями. Если нет, написать комментарий, что таких нет.

# %%
df_ex8.isnull()
# Out:
#        mode  price  income  catch  pbeach  ppier  pboat  pcharter  cbeach  cpier  cboat  ccharter  \
# 1     False  False   False  False   False  False  False     False   False  False  False     False
# 2     False  False   False  False   False  False  False     False   False  False  False     False
# 3     False  False   False  False   False  False  False     False   False  False  False     False
# 4     False  False   False  False   False  False  False     False   False  False  False     False
# 5     False  False   False  False   False  False  False     False   False  False  False     False
# ...     ...    ...     ...    ...     ...    ...    ...       ...     ...    ...    ...       ...
# 1178  False  False   False  False   False  False  False     False   False  False  False     False
# 1179  False  False   False  False   False  False  False     False   False  False  False     False
# 1180  False  False   False  False   False  False  False     False   False  False  False     False
# 1181  False  False   False  False   False  False  False     False   False  False  False     False
# 1182  False  False   False  False   False  False  False     False   False  False  False     False
#
#       log_income  pdiff
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False
# 5          False  False
# ...          ...    ...
# 1178       False  False
# 1179       False  False
# 1180       False  False
# 1181       False  False
# 1182       False  False
#
# [1182 rows x 14 columns]

# %%
df_ex8.isnull().sum()
# Out:
# mode          0
# price         0
# income        0
# catch         0
# pbeach        0
# ppier         0
# pboat         0
# pcharter      0
# cbeach        0
# cpier         0
# cboat         0
# ccharter      0
# log_income    0
# pdiff         0
# dtype: int64

# %% [markdown]
# .<br> .<br> .<br> .<br> .<br> .<br> .<br> .<br> .<br> .<br> .<br> .<br> .<br> .<br> .<br> .<br> .<br> .<br>
# # Дополнительное (необязательное) задание.
# <br>

# %% [markdown]
# ### Задание 1
#
# Загрузить датафрейм из файла `wgi_fh.csv`, учитывая, что в качестве разделителя столбцов используется точка с запятой, а в качестве десятичного разделителя – запятая (опции `sep=` и `decimal=` в функции `read_csv()` соответственно).
#
# Файл содержит данные за 2016 по различным политологическим индексам. Датафрейм содержит следующие столбцы:
#
# * `country`: страна;
# * `cnt_code`: код страны (аббревиатура);
# * `year`: год;
# * `va`: индекс подотчётности *Voice & Accountability (WGI)*;
# * `ps`: индекс политической стабильности *Political Stability and Lack of Violence (WGI)*;
# * `ge`: индекс эффективности правительства *Government Effectiveness (WGI)*;
# * `rq`: индекс качества управления *Regulatory Quality (WGI)*;
# * `rl`: индекс верховенства закона *Rule of Law (WGI)*;
# * `cc`: индекс контроля коррупции *Control of Corruption (WGI)*;
# * `fh`: индекс свободы *Freedom House (Freedom Rating)*.
#
# Подробнее про индексы можно почитать на этой [странице](https://www.hse.ru/org/hse/4432173/mathbase/databases/db_18).

# %%
import pandas as pd

# %%
import numpy as np

# %%
df_13_dop = pd.read_csv('[DMC.RIP] wgi_fh.csv',sep = ';', decimal = ',')

# %%
df_13_dop
# Out:
#               country cnt_code  year    va    ps    ge    rq    rl    cc   fh
# 0               Aruba      ABW  2016  1.27  1.28  0.90  1.35  1.29  1.29  NaN
# 1             Andorra      ADO  2016  1.20  1.40  1.86  0.87  1.56  1.23  1.0
# 2         Afghanistan      AFG  2016 -1.09 -2.75 -1.22 -1.33 -1.62 -1.56  6.0
# 3              Angola      AGO  2016 -1.17 -0.39 -1.04 -1.00 -1.08 -1.41  6.0
# 4            Anguilla      AIA  2016   NaN  1.31  1.33  0.87 -0.09  1.23  NaN
# ..                ...      ...   ...   ...   ...   ...   ...   ...   ...  ...
# 209            Serbia      SRB  2016  0.21  0.05  0.09  0.06 -0.12 -0.31  2.0
# 210      South Africa      ZAF  2016  0.64 -0.13  0.27  0.21  0.07  0.05  2.0
# 211  Congo, Dem. Rep.      ZAR  2016 -1.39 -2.20 -1.51 -1.32 -1.61 -1.33  6.0
# 212            Zambia      ZMB  2016 -0.30  0.18 -0.66 -0.48 -0.30 -0.40  3.5
# 213          Zimbabwe      ZWE  2016 -1.11 -0.61 -1.16 -1.72 -1.32 -1.28  5.0
#
# [214 rows x 10 columns]

# %% [markdown]
# ### Задание 2
#
# Вывести общую информацию по датафрейму: число строк и столбцов, типы данных в таблице. Есть ли в таблице пропущенные значения? Привести код и дать ответ в виде комментария.

# %%
df_13_dop.info
# Out:
# <bound method DataFrame.info of               country cnt_code  year    va    ps    ge    rq    rl    cc   fh
# 0               Aruba      ABW  2016  1.27  1.28  0.90  1.35  1.29  1.29  NaN
# 1             Andorra      ADO  2016  1.20  1.40  1.86  0.87  1.56  1.23  1.0
# 2         Afghanistan      AFG  2016 -1.09 -2.75 -1.22 -1.33 -1.62 -1.56  6.0
# 3              Angola      AGO  2016 -1.17 -0.39 -1.04 -1.00 -1.08 -1.41  6.0
# 4            Anguilla      AIA  2016   NaN  1.31  1.33  0.87 -0.09  1.23  NaN
# ..                ...      ...   ...   ...   ...   ...   ...   ...   ...  ...
# 209            Serbia      SRB  2016  0.21  0.05  0.09  0.06 -0.12 -0.31  2.0
# 210      South Africa      ZAF  2016  0.64 -0.13  0.27  0.21  0.07  0.05  2.0
# 211  Congo, Dem. Rep.      ZAR  2016 -1.39 -2.20 -1.51 -1.32 -1.61 -1.33  6.0
# 212            Zambia      ZMB  2016 -0.30  0.18 -0.66 -0.48 -0.30 -0.40  3.5
# 213          Zimbabwe      ZWE  2016 -1.11 -0.61 -1.16 -1.72 -1.32 -1.28  5.0
#
# [214 rows x 10 columns]>

# %%
df_13_dop.isnull().sum().sum()
# Out:
# 50

# %% [markdown]
# ### Задание 3
#
# Если в датафрейме есть строки с пропущенными значениями, удалить их. Сохранить изменения в исходном датафрейме.

# %%
df_13_dop = df_13_dop.dropna()

# %%
df_13_dop.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Задание 4
#
# Назвать строки в датафрейме в соответствии со столбцом `cnt_code`. Удалить данный столбец из датафрейма.

# %%
df_13_dop.head(5)
# Out:
#        country cnt_code  year    va    ps    ge    rq    rl    cc   fh
# 1      Andorra      ADO  2016  1.20  1.40  1.86  0.87  1.56  1.23  1.0
# 2  Afghanistan      AFG  2016 -1.09 -2.75 -1.22 -1.33 -1.62 -1.56  6.0
# 3       Angola      AGO  2016 -1.17 -0.39 -1.04 -1.00 -1.08 -1.41  6.0
# 5      Albania      ALB  2016  0.16  0.26  0.00  0.19 -0.35 -0.40  3.0
# 8    Argentina      ARG  2016  0.54  0.22  0.18 -0.47 -0.35 -0.31  2.0

# %%
df_13_dop.loc[:,'cnt_code'] = 'cnt_code'
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df_13_dop.head(5)
# Out:
#        country  cnt_code  year    va    ps    ge    rq    rl    cc   fh
# 1      Andorra  cnt_code  2016  1.20  1.40  1.86  0.87  1.56  1.23  1.0
# 2  Afghanistan  cnt_code  2016 -1.09 -2.75 -1.22 -1.33 -1.62 -1.56  6.0
# 3       Angola  cnt_code  2016 -1.17 -0.39 -1.04 -1.00 -1.08 -1.41  6.0
# 5      Albania  cnt_code  2016  0.16  0.26  0.00  0.19 -0.35 -0.40  3.0
# 8    Argentina  cnt_code  2016  0.54  0.22  0.18 -0.47 -0.35 -0.31  2.0

# %%
del df_13_dop['cnt_code']

# %%
df_13_dop.head(5)
# Out:
#        country  year    va    ps    ge    rq    rl    cc   fh
# 1      Andorra  2016  1.20  1.40  1.86  0.87  1.56  1.23  1.0
# 2  Afghanistan  2016 -1.09 -2.75 -1.22 -1.33 -1.62 -1.56  6.0
# 3       Angola  2016 -1.17 -0.39 -1.04 -1.00 -1.08 -1.41  6.0
# 5      Albania  2016  0.16  0.26  0.00  0.19 -0.35 -0.40  3.0
# 8    Argentina  2016  0.54  0.22  0.18 -0.47 -0.35 -0.31  2.0

# %% [markdown]
# ### Задание 5
#
# Отсортировать строки в таблице в соответствии со значениями столбцов с индексами *Control of Corruption*  и *Voice & Accountability* таким образом, чтобы результаты сортировки были сохранены сразу в исходном датафрейме.

# %%
df_13_dop = df_13_dop.sort_values(['cc','va'])

# %%
df_13_dop.reset_index(drop=True, inplace=True)

# %%
df_13_dop.head(5)
# Out:
#              country  year    va    ps    ge    rq    rl    cc   fh
# 0  Equatorial Guinea  2016 -1.93 -0.19 -1.41 -1.38 -1.44 -1.81  7.0
# 1            Somalia  2016 -1.83 -2.33 -2.18 -2.27 -2.37 -1.69  7.0
# 2        Yemen, Rep.  2016 -1.65 -2.79 -1.82 -1.48 -1.60 -1.67  6.5
# 3              Sudan  2016 -1.80 -2.38 -1.41 -1.49 -1.26 -1.61  7.0
# 4        South Sudan  2016 -1.67 -2.42 -2.26 -1.86 -1.69 -1.58  6.5

# %% [markdown]
# ### Задание 6
#
# Используя метод `.apply()`, создать столбец `cc_round` со значениями индекса *Control of Corruption*, округлёнными до первого знака после запятой.

# %%
df_13_dop['cc_round'] = np.round(df_13_dop['cc'], 1)

# %%
df_13_dop.head(7)
# Out:
#                 country  year    va    ps    ge    rq    rl    cc   fh  \
# 0     Equatorial Guinea  2016 -1.93 -0.19 -1.41 -1.38 -1.44 -1.81  7.0
# 1               Somalia  2016 -1.83 -2.33 -2.18 -2.27 -2.37 -1.69  7.0
# 2           Yemen, Rep.  2016 -1.65 -2.79 -1.82 -1.48 -1.60 -1.67  6.5
# 3                 Sudan  2016 -1.80 -2.38 -1.41 -1.49 -1.26 -1.61  7.0
# 4           South Sudan  2016 -1.67 -2.42 -2.26 -1.86 -1.69 -1.58  6.5
# 5  Syrian Arab Republic  2016 -1.96 -2.91 -1.82 -1.67 -2.01 -1.57  7.0
# 6                 Libya  2016 -1.37 -2.21 -1.89 -2.27 -1.87 -1.57  6.0
#
#    cc_round
# 0      -1.8
# 1      -1.7
# 2      -1.7
# 3      -1.6
# 4      -1.6
# 5      -1.6
# 6      -1.6

# %% [markdown]
# ### Задание 7
#
# Добавить в датафрейм столбец `fh_status`, в котором будут храниться типы стран в зависимости от значения индекса *Freedom House* (значения типов стран: `"free"`, `"partly free"`, `"not free"`). Соответствие значений `fh` типам стран см. в Table 3 в конце [этой](https://freedomhouse.org/sites/default/files/2020-02/Methodology_FIW_2016.pdf) страницы.

# %%
def func(x):
    if 1.0 <= x <= 2.5:
        return 'Free'
    elif 3.0 <= x <=  5.0:
        return 'Partly Free'
    elif 5.5 <= x <=  7.0:
        return 'Not Free'
    else:
        return 'NaN'

# %%
func(2)
# Out:
# 'Free'

# %%
df_13_dop.head(3)
# Out:
#              country  year    va    ps    ge    rq    rl    cc   fh  cc_round
# 0  Equatorial Guinea  2016 -1.93 -0.19 -1.41 -1.38 -1.44 -1.81  7.0      -1.8
# 1            Somalia  2016 -1.83 -2.33 -2.18 -2.27 -2.37 -1.69  7.0      -1.7
# 2        Yemen, Rep.  2016 -1.65 -2.79 -1.82 -1.48 -1.60 -1.67  6.5      -1.7

# %%
df_13_dop['fh_status'] = df_13_dop['fh'].apply(func)

# %%
df_13_dop.head(3)
# Out:
#              country  year    va    ps    ge    rq    rl    cc   fh  cc_round  \
# 0  Equatorial Guinea  2016 -1.93 -0.19 -1.41 -1.38 -1.44 -1.81  7.0      -1.8
# 1            Somalia  2016 -1.83 -2.33 -2.18 -2.27 -2.37 -1.69  7.0      -1.7
# 2        Yemen, Rep.  2016 -1.65 -2.79 -1.82 -1.48 -1.60 -1.67  6.5      -1.7
#
#   fh_status
# 0  Not Free
# 1  Not Free
# 2  Not Free

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df_13_dop) # разовый показ
# Out:
#                             country  year    va    ps    ge    rq    rl    cc  \
# 0                 Equatorial Guinea  2016 -1.93 -0.19 -1.41 -1.38 -1.44 -1.81
# 1                           Somalia  2016 -1.83 -2.33 -2.18 -2.27 -2.37 -1.69
# 2                       Yemen, Rep.  2016 -1.65 -2.79 -1.82 -1.48 -1.60 -1.67
# 3                             Sudan  2016 -1.80 -2.38 -1.41 -1.49 -1.26 -1.61
# 4                       South Sudan  2016 -1.67 -2.42 -2.26 -1.86 -1.69 -1.58
# 5              Syrian Arab Republic  2016 -1.96 -2.91 -1.82 -1.67 -2.01 -1.57
# 6                             Libya  2016 -1.37 -2.21 -1.89 -2.27 -1.87 -1.57
# 7                       Afghanistan  2016 -1.09 -2.75 -1.22 -1.33 -1.62 -1.56
# 8                     Guinea-Bissau  2016 -0.70 -0.50 -1.64 -1.24 -1.49 -1.56
# 9                      Turkmenistan  2016 -2.13 -0.31 -1.14 -2.09 -1.56 -1.46
# 10                 Korea, Dem. Rep.  2016 -2.13 -0.71 -1.65 -2.33 -1.63 -1.45
# 11                             Chad  2016 -1.34 -1.21 -1.49 -1.18 -1.43 -1.45
# 12                           Angola  2016 -1.17 -0.39 -1.04 -1.00 -1.08 -1.41
# 13                             Iraq  2016 -1.01 -2.28 -1.26 -1.13 -1.70 -1.40
# 14                    Venezuela, RB  2016 -1.13 -1.03 -1.29 -2.00 -2.18 -1.39
# 15                            Haiti  2016 -0.73 -0.67 -2.06 -1.24 -1.00 -1.35
# 16                 Congo, Dem. Rep.  2016 -1.39 -2.20 -1.51 -1.32 -1.61 -1.33
# 17                         Cambodia  2016 -1.14  0.18 -0.69 -0.47 -1.10 -1.30
# 18         Central African Republic  2016 -1.13 -1.74 -1.77 -1.43 -1.84 -1.28
# 19                         Zimbabwe  2016 -1.11 -0.61 -1.16 -1.72 -1.32 -1.28
# 20                      Congo, Rep.  2016 -1.16 -0.57 -1.10 -1.17 -1.04 -1.21
# 21                       Uzbekistan  2016 -1.89 -0.34 -0.60 -1.62 -1.13 -1.20
# 22                          Burundi  2016 -1.51 -2.08 -1.40 -0.83 -1.39 -1.18
# 23                         Cameroon  2016 -1.03 -0.95 -0.76 -0.79 -1.02 -1.14
# 24                          Eritrea  2016 -2.10 -0.88 -1.69 -2.19 -1.53 -1.13
# 25                  Kyrgyz Republic  2016 -0.49 -0.66 -0.90 -0.35 -1.10 -1.08
# 26                       Tajikistan  2016 -1.67 -0.79 -1.02 -1.09 -1.18 -1.07
# 27                           Uganda  2016 -0.71 -0.72 -0.57 -0.21 -0.24 -1.06
# 28                          Nigeria  2016 -0.30 -1.85 -1.09 -0.92 -1.05 -1.04
# 29                          Lebanon  2016 -0.52 -1.56 -0.53 -0.34 -0.86 -0.97
# 30                          Moldova  2016 -0.03 -0.28 -0.62 -0.12 -0.54 -0.96
# 31                           Guinea  2016 -0.73 -0.41 -1.01 -0.87 -1.29 -0.94
# 32                          Lao PDR  2016 -1.73  0.50 -0.39 -0.73 -0.77 -0.93
# 33                 Papua New Guinea  2016  0.19 -0.50 -0.73 -0.56 -0.75 -0.92
# 34                       Madagascar  2016 -0.27 -0.40 -1.17 -0.69 -0.74 -0.90
# 35                            Kenya  2016 -0.15 -1.33 -0.31 -0.30 -0.53 -0.90
# 36                        Nicaragua  2016 -0.63 -0.17 -0.70 -0.51 -0.60 -0.89
# 37                       Azerbaijan  2016 -1.60 -0.87 -0.16 -0.28 -0.57 -0.87
# 38                       Mozambique  2016 -0.39 -1.05 -0.85 -0.70 -1.02 -0.87
# 39               Russian Federation  2016 -1.21 -0.89 -0.22 -0.42 -0.80 -0.86
# 40                         Pakistan  2016 -0.69 -2.47 -0.64 -0.64 -0.83 -0.86
# 41                          Ukraine  2016  0.02 -1.89 -0.58 -0.43 -0.77 -0.84
# 42                     Sierra Leone  2016 -0.13 -0.16 -1.20 -0.93 -0.79 -0.82
# 43                       Kazakhstan  2016 -1.29  0.04 -0.06 -0.10 -0.42 -0.80
# 44                      Gambia, The  2016 -1.28 -0.52 -0.84 -0.51 -0.75 -0.80
# 45                       Mauritania  2016 -0.83 -0.74 -0.79 -0.74 -0.78 -0.80
# 46                       Bangladesh  2016 -0.56 -1.24 -0.69 -0.80 -0.59 -0.80
# 47               Dominican Republic  2016  0.19  0.29 -0.25 -0.07 -0.29 -0.78
# 48                           Mexico  2016 -0.09 -0.77  0.14  0.29 -0.50 -0.77
# 49                            Nepal  2016 -0.23 -0.79 -0.81 -0.76 -0.84 -0.76
# 50                            Gabon  2016 -0.96 -0.07 -0.79 -0.80 -0.58 -0.75
# 51                         Paraguay  2016 -0.04  0.20 -0.77 -0.30 -0.67 -0.75
# 52                           Malawi  2016  0.04 -0.06 -0.73 -0.84 -0.37 -0.75
# 53                        Guatemala  2016 -0.31 -0.54 -0.60 -0.20 -1.04 -0.74
# 54               Iran, Islamic Rep.  2016 -1.39 -0.74 -0.20 -1.23 -0.71 -0.72
# 55                          Liberia  2016 -0.10 -0.55 -1.32 -0.95 -0.97 -0.71
# 56                          Bolivia  2016  0.01 -0.21 -0.57 -0.92 -1.20 -0.71
# 57                          Algeria  2016 -0.88 -1.14 -0.54 -1.17 -0.85 -0.69
# 58                         Honduras  2016 -0.43 -0.36 -0.73 -0.51 -1.11 -0.69
# 59                             Togo  2016 -0.51 -0.20 -1.08 -0.79 -0.68 -0.68
# 60                         Maldives  2016 -0.74  0.41 -0.33 -0.46 -0.41 -0.67
# 61                          Ecuador  2016 -0.25 -0.10 -0.43 -1.02 -0.69 -0.67
# 62                             Mali  2016 -0.18 -1.55 -0.99 -0.59 -0.78 -0.67
# 63                         Djibouti  2016 -1.32 -0.63 -0.97 -0.70 -0.97 -0.65
# 64                          Myanmar  2016 -0.85 -0.63 -0.98 -0.87 -0.99 -0.65
# 65                            Niger  2016 -0.34 -1.08 -0.59 -0.67 -0.64 -0.64
# 66                          Comoros  2016 -0.18 -0.02 -1.54 -1.05 -1.13 -0.64
# 67                 Egypt, Arab Rep.  2016 -1.23 -1.42 -0.66 -0.92 -0.41 -0.63
# 68                          Armenia  2016 -0.62 -0.60 -0.15  0.25 -0.11 -0.57
# 69                      El Salvador  2016  0.28 -0.06 -0.28  0.09 -0.71 -0.57
# 70                    Côte d'Ivoire  2016 -0.28 -0.90 -0.67 -0.36 -0.67 -0.54
# 71                      Philippines  2016  0.14 -1.30 -0.01  0.00 -0.40 -0.53
# 72                         Tanzania  2016 -0.18 -0.41 -0.55 -0.44 -0.39 -0.51
# 73                      Timor-Leste  2016  0.24 -0.08 -1.03 -0.98 -1.20 -0.51
# 74                         Mongolia  2016  0.45  0.82 -0.11 -0.08 -0.22 -0.50
# 75                           Panama  2016  0.53  0.43  0.19  0.36  0.03 -0.49
# 76                            Benin  2016  0.50  0.05 -0.57 -0.53 -0.65 -0.48
# 77           Bosnia and Herzegovina  2016 -0.16 -0.38 -0.43 -0.17 -0.29 -0.47
# 78                            Nauru  2016  0.52  0.55 -0.69 -0.38 -0.80 -0.47
# 79                            Palau  2016  1.23  0.93 -0.41 -0.18  0.32 -0.47
# 80                         Ethiopia  2016 -1.45 -1.57 -0.64 -1.10 -0.39 -0.44
# 81                        Swaziland  2016 -1.42 -0.49 -0.56 -0.58 -0.32 -0.44
# 82                           Brazil  2016  0.47 -0.45 -0.18 -0.21 -0.08 -0.44
# 83                            Tonga  2016  0.67  0.91 -0.29 -0.41  0.24 -0.44
# 84                           Kosovo  2016 -0.16 -0.20 -0.44 -0.19 -0.38 -0.42
# 85                          Vietnam  2016 -1.41  0.17  0.01 -0.45  0.05 -0.40
# 86                         Thailand  2016 -1.10 -0.93  0.34  0.17  0.01 -0.40
# 87                           Zambia  2016 -0.30  0.18 -0.66 -0.48 -0.30 -0.40
# 88                          Albania  2016  0.16  0.26  0.00  0.19 -0.35 -0.40
# 89                        Indonesia  2016  0.14 -0.38  0.01 -0.12 -0.36 -0.39
# 90                             Peru  2016  0.28 -0.16 -0.17  0.51 -0.49 -0.35
# 91                         Colombia  2016  0.10 -0.96  0.02  0.40 -0.32 -0.34
# 92                  Solomon Islands  2016  0.49  0.51 -0.99 -0.96 -0.34 -0.34
# 93                           Guyana  2016  0.30 -0.03 -0.30 -0.42 -0.31 -0.32
# 94                         Suriname  2016  0.46  0.27 -0.34 -0.63 -0.12 -0.32
# 95                   Macedonia, FYR  2016 -0.23 -0.38  0.09  0.44 -0.31 -0.31
# 96                           Serbia  2016  0.21  0.05  0.09  0.06 -0.12 -0.31
# 97                        Argentina  2016  0.54  0.22  0.18 -0.47 -0.35 -0.31
# 98                            India  2016  0.41 -0.95  0.10 -0.31 -0.07 -0.30
# 99                          Belarus  2016 -1.39  0.12 -0.51 -0.94 -0.78 -0.29
# 100                       Sri Lanka  2016 -0.11  0.07 -0.21 -0.10 -0.01 -0.28
# 101             Trinidad and Tobago  2016  0.60  0.28  0.22  0.09 -0.16 -0.26
# 102                           China  2016 -1.62 -0.52  0.36 -0.26 -0.22 -0.25
# 103                          Belize  2016  0.67  0.06 -0.68 -0.51 -0.86 -0.24
# 104                          Kuwait  2016 -0.69 -0.15 -0.18 -0.07  0.03 -0.20
# 105                          Turkey  2016 -0.63 -2.00  0.05  0.20 -0.16 -0.20
# 106                           Ghana  2016  0.64 -0.16 -0.20 -0.23  0.00 -0.17
# 107                        Bulgaria  2016  0.44  0.03  0.29  0.66 -0.04 -0.16
# 108                         Jamaica  2016  0.69  0.24  0.41  0.16 -0.25 -0.16
# 109              West Bank and Gaza  2016 -1.17 -2.10 -0.62  0.06 -0.31 -0.15
# 110                         Morocco  2016 -0.65 -0.29 -0.10 -0.23 -0.14 -0.15
# 111                    Burkina Faso  2016  0.04 -0.95 -0.55 -0.40 -0.45 -0.13
# 112                         Tunisia  2016  0.33 -0.99 -0.21 -0.47  0.02 -0.12
# 113                      Montenegro  2016  0.08  0.16  0.10  0.22 -0.04 -0.10
# 114                         Vanuatu  2016  0.69  0.51 -0.88 -0.29  0.32 -0.10
# 115                         Bahrain  2016 -1.45 -0.86  0.32  0.61  0.46 -0.06
# 116           São Tomé and Principe  2016  0.45  0.23 -0.68 -0.81 -0.69 -0.06
# 117                Marshall Islands  2016  1.20  0.93 -1.56 -0.98 -0.10 -0.06
# 118                          Greece  2016  0.65 -0.14  0.21  0.15  0.20 -0.05
# 119                         Senegal  2016  0.37 -0.27 -0.47 -0.14 -0.19 -0.03
# 120                         Lesotho  2016  0.03 -0.25 -0.80 -0.39 -0.18 -0.02
# 121                         Romania  2016  0.51  0.27 -0.17  0.59  0.30  0.00
# 122                          Tuvalu  2016  1.09  1.40 -0.93 -0.59  0.46  0.03
# 123                     Puerto Rico  2016  0.40  0.81  0.38  0.95  0.68  0.04
# 124                            Cuba  2016 -1.63  0.62 -0.13 -1.34 -0.41  0.05
# 125                    South Africa  2016  0.64 -0.13  0.27  0.21  0.07  0.05
# 126                           Italy  2016  1.04  0.35  0.52  0.71  0.27  0.05
# 127                         Hungary  2016  0.37  0.71  0.45  0.60  0.51  0.08
# 128                        Malaysia  2016 -0.47  0.10  0.88  0.71  0.54  0.11
# 129                            Fiji  2016 -0.03  0.83 -0.26 -0.38 -0.29  0.13
# 130                         Croatia  2016  0.52  0.68  0.49  0.36  0.44  0.19
# 131                    Saudi Arabia  2016 -1.78 -0.50  0.24  0.08  0.47  0.23
# 132                 Slovak Republic  2016  0.94  0.62  0.89  0.89  0.69  0.24
# 133                        Kiribati  2016  1.03  0.87 -0.45 -0.84  0.21  0.25
# 134                          Jordan  2016 -0.76 -0.53  0.14  0.05  0.31  0.27
# 135                           Samoa  2016  0.76  1.19  0.54 -0.10  0.76  0.28
# 136                       Mauritius  2016  0.86  1.05  0.96  1.03  0.80  0.32
# 137                            Oman  2016 -1.11  0.80  0.19  0.61  0.43  0.37
# 138                         Namibia  2016  0.61  0.74  0.17 -0.14  0.39  0.37
# 139                     Korea, Rep.  2016  0.63  0.17  1.07  1.11  1.14  0.37
# 140                          Latvia  2016  0.87  0.39  1.00  1.08  0.95  0.49
# 141                  Czech Republic  2016  1.05  0.99  1.06  0.99  1.09  0.51
# 142                           Spain  2016  1.06  0.49  1.12  1.01  0.98  0.52
# 143             St. Kitts and Nevis  2016  1.07  0.62  0.14  0.37  0.51  0.52
# 144                         Grenada  2016  0.86  1.01 -0.18  0.08  0.57  0.57
# 145                        Dominica  2016  0.99  1.13  0.05  0.20  0.61  0.63
# 146                       St. Lucia  2016  1.09  0.86  0.01  0.29  0.51  0.63
# 147           Micronesia, Fed. Sts.  2016  1.16  1.05 -0.35 -0.97 -0.06  0.65
# 148               Brunei Darussalam  2016 -0.95  1.26  1.07  0.59  0.62  0.66
# 149                         Georgia  2016  0.22 -0.29  0.51  1.01  0.37  0.67
# 150                       Lithuania  2016  0.99  0.80  1.09  1.14  1.02  0.67
# 151  St. Vincent and the Grenadines  2016  1.04  1.01  0.21  0.28  0.41  0.68
# 152                          Rwanda  2016 -1.21 -0.05  0.11  0.11  0.07  0.69
# 153             Antigua and Barbuda  2016  0.65  1.01  0.27  0.34  0.51  0.69
# 154                      Costa Rica  2016  1.14  0.75  0.36  0.41  0.46  0.70
# 155                           Malta  2016  1.20  1.08  0.95  1.16  1.08  0.72
# 156                          Poland  2016  0.84  0.51  0.69  0.95  0.68  0.75
# 157                      Seychelles  2016  0.16  0.72  0.36 -0.26  0.13  0.79
# 158                        Slovenia  2016  1.00  0.99  1.12  0.64  1.08  0.80
# 159                          Cyprus  2016  1.08  0.57  0.98  1.05  0.73  0.82
# 160                   Taiwan, China  2016  1.04  0.93  1.37  1.29  1.14  0.86
# 161                      Cape Verde  2016  1.02  0.88  0.10 -0.30  0.35  0.88
# 162                           Qatar  2016 -1.20  0.87  0.75  0.70  0.86  0.92
# 163                        Botswana  2016  0.42  1.09  0.51  0.53  0.52  0.93
# 164                        Portugal  2016  1.17  1.02  1.22  0.84  1.13  0.96
# 165                          Israel  2016  0.77 -0.83  1.35  1.31  1.02  1.06
# 166                           Chile  2016  1.00  0.51  1.02  1.37  1.13  1.11
# 167                    Bahamas, The  2016  0.94  0.90  0.72  0.26  0.23  1.13
# 168                          Bhutan  2016 -0.05  0.99  0.49 -0.67  0.47  1.14
# 169                         Estonia  2016  1.20  0.69  1.12  1.70  1.24  1.21
# 170                         Andorra  2016  1.20  1.40  1.86  0.87  1.56  1.23
# 171                        Barbados  2016  1.10  0.96  1.08  0.48  0.78  1.24
# 172                         Uruguay  2016  1.18  1.10  0.55  0.49  0.63  1.32
# 173                   United States  2016  1.10  0.35  1.48  1.50  1.67  1.33
# 174                          France  2016  1.08 -0.06  1.41  1.07  1.41  1.37
# 175                           Japan  2016  1.00  1.01  1.83  1.43  1.38  1.51
# 176                         Austria  2016  1.29  0.82  1.51  1.44  1.78  1.54
# 177            Hong Kong SAR, China  2016  0.27  0.84  1.86  2.15  1.70  1.58
# 178                         Belgium  2016  1.35  0.48  1.33  1.34  1.40  1.60
# 179                         Ireland  2016  1.29  0.88  1.35  1.74  1.54  1.63
# 180                       Australia  2016  1.30  0.96  1.58  1.90  1.75  1.77
# 181                         Germany  2016  1.33  0.76  1.74  1.82  1.61  1.83
# 182                  United Kingdom  2016  1.24  0.38  1.61  1.76  1.63  1.88
# 183                     Netherlands  2016  1.48  0.89  1.84  1.98  1.89  1.95
# 184                          Canada  2016  1.38  1.24  1.80  1.74  1.84  1.98
# 185                         Iceland  2016  1.34  1.33  1.41  1.28  1.51  1.99
# 186                   Liechtenstein  2016  1.19  1.46  1.70  1.37  1.68  2.05
# 187                     Switzerland  2016  1.46  1.32  2.03  1.91  1.94  2.05
# 188                       Singapore  2016 -0.28  1.53  2.21  2.18  1.83  2.07
# 189                      Luxembourg  2016  1.44  1.41  1.69  1.72  1.71  2.08
# 190                          Norway  2016  1.58  1.17  1.88  1.70  2.02  2.20
# 191                          Sweden  2016  1.50  0.98  1.79  1.85  2.04  2.22
# 192                         Denmark  2016  1.47  0.85  1.89  1.58  1.90  2.24
# 193                         Finland  2016  1.49  0.96  1.85  1.82  2.02  2.28
# 194                     New Zealand  2016  1.44  1.49  1.86  2.04  1.93  2.30
#
#       fh  cc_round    fh_status
# 0    7.0      -1.8     Not Free
# 1    7.0      -1.7     Not Free
# 2    6.5      -1.7     Not Free
# 3    7.0      -1.6     Not Free
# 4    6.5      -1.6     Not Free
# 5    7.0      -1.6     Not Free
# 6    6.0      -1.6     Not Free
# 7    6.0      -1.6     Not Free
# 8    5.0      -1.6  Partly Free
# 9    7.0      -1.5     Not Free
# 10   7.0      -1.4     Not Free
# 11   6.5      -1.4     Not Free
# 12   6.0      -1.4     Not Free
# 13   5.5      -1.4     Not Free
# 14   5.0      -1.4  Partly Free
# 15   5.0      -1.4  Partly Free
# 16   6.0      -1.3     Not Free
# 17   5.5      -1.3     Not Free
# 18   7.0      -1.3     Not Free
# 19   5.0      -1.3  Partly Free
# 20   5.5      -1.2     Not Free
# 21   7.0      -1.2     Not Free
# 22   6.5      -1.2     Not Free
# 23   6.0      -1.1     Not Free
# 24   7.0      -1.1     Not Free
# 25   5.0      -1.1  Partly Free
# 26   6.5      -1.1     Not Free
# 27   5.5      -1.1     Not Free
# 28   4.5      -1.0  Partly Free
# 29   4.5      -1.0  Partly Free
# 30   3.0      -1.0  Partly Free
# 31   5.0      -0.9  Partly Free
# 32   6.5      -0.9     Not Free
# 33   3.5      -0.9  Partly Free
# 34   3.5      -0.9  Partly Free
# 35   4.0      -0.9  Partly Free
# 36   3.5      -0.9  Partly Free
# 37   6.5      -0.9     Not Free
# 38   4.0      -0.9  Partly Free
# 39   6.0      -0.9     Not Free
# 40   4.5      -0.9  Partly Free
# 41   3.0      -0.8  Partly Free
# 42   3.0      -0.8  Partly Free
# 43   5.5      -0.8     Not Free
# 44   6.5      -0.8     Not Free
# 45   5.5      -0.8     Not Free
# 46   4.0      -0.8  Partly Free
# 47   3.0      -0.8  Partly Free
# 48   3.0      -0.8  Partly Free
# 49   3.5      -0.8  Partly Free
# 50   5.5      -0.8     Not Free
# 51   3.0      -0.8  Partly Free
# 52   3.0      -0.8  Partly Free
# 53   4.0      -0.7  Partly Free
# 54   6.0      -0.7     Not Free
# 55   3.5      -0.7  Partly Free
# 56   3.0      -0.7  Partly Free
# 57   5.5      -0.7     Not Free
# 58   4.0      -0.7  Partly Free
# 59   4.0      -0.7  Partly Free
# 60   4.5      -0.7  Partly Free
# 61   3.0      -0.7  Partly Free
# 62   4.5      -0.7  Partly Free
# 63   5.5      -0.6     Not Free
# 64   5.5      -0.6     Not Free
# 65   3.5      -0.6  Partly Free
# 66   3.5      -0.6  Partly Free
# 67   5.5      -0.6     Not Free
# 68   4.5      -0.6  Partly Free
# 69   2.5      -0.6         Free
# 70   4.0      -0.5  Partly Free
# 71   3.0      -0.5  Partly Free
# 72   3.5      -0.5  Partly Free
# 73   3.0      -0.5  Partly Free
# 74   1.5      -0.5         Free
# 75   2.0      -0.5         Free
# 76   2.0      -0.5         Free
# 77   3.5      -0.5  Partly Free
# 78   2.0      -0.5         Free
# 79   1.0      -0.5         Free
# 80   6.5      -0.4     Not Free
# 81   6.0      -0.4     Not Free
# 82   2.0      -0.4         Free
# 83   2.0      -0.4         Free
# 84   3.5      -0.4  Partly Free
# 85   6.0      -0.4     Not Free
# 86   5.5      -0.4     Not Free
# 87   3.5      -0.4  Partly Free
# 88   3.0      -0.4  Partly Free
# 89   3.0      -0.4  Partly Free
# 90   2.5      -0.4         Free
# 91   3.5      -0.3  Partly Free
# 92   3.0      -0.3  Partly Free
# 93   2.5      -0.3         Free
# 94   2.5      -0.3         Free
# 95   3.5      -0.3  Partly Free
# 96   2.0      -0.3         Free
# 97   2.0      -0.3         Free
# 98   2.5      -0.3         Free
# 99   6.5      -0.3     Not Free
# 100  4.0      -0.3  Partly Free
# 101  2.0      -0.3         Free
# 102  6.5      -0.2     Not Free
# 103  1.5      -0.2         Free
# 104  5.0      -0.2  Partly Free
# 105  3.5      -0.2  Partly Free
# 106  1.5      -0.2         Free
# 107  2.0      -0.2         Free
# 108  2.5      -0.2         Free
# 109  5.5      -0.2     Not Free
# 110  4.5      -0.2  Partly Free
# 111  3.5      -0.1  Partly Free
# 112  2.0      -0.1         Free
# 113  3.0      -0.1  Partly Free
# 114  2.0      -0.1         Free
# 115  6.5      -0.1     Not Free
# 116  2.0      -0.1         Free
# 117  1.0      -0.1         Free
# 118  2.0      -0.0         Free
# 119  2.0      -0.0         Free
# 120  3.0      -0.0  Partly Free
# 121  2.0       0.0         Free
# 122  1.0       0.0         Free
# 123  1.0       0.0         Free
# 124  6.5       0.0     Not Free
# 125  2.0       0.0         Free
# 126  1.0       0.0         Free
# 127  2.0       0.1         Free
# 128  4.0       0.1  Partly Free
# 129  3.0       0.1  Partly Free
# 130  1.5       0.2         Free
# 131  7.0       0.2     Not Free
# 132  1.0       0.2         Free
# 133  1.0       0.2         Free
# 134  5.5       0.3     Not Free
# 135  2.0       0.3         Free
# 136  1.5       0.3         Free
# 137  5.5       0.4     Not Free
# 138  2.0       0.4         Free
# 139  2.0       0.4         Free
# 140  2.0       0.5         Free
# 141  1.0       0.5         Free
# 142  1.0       0.5         Free
# 143  1.5       0.5         Free
# 144  1.5       0.6         Free
# 145  1.0       0.6         Free
# 146  1.0       0.6         Free
# 147  1.0       0.6         Free
# 148  5.5       0.7     Not Free
# 149  3.0       0.7  Partly Free
# 150  1.0       0.7         Free
# 151  1.0       0.7         Free
# 152  6.0       0.7     Not Free
# 153  2.0       0.7         Free
# 154  1.0       0.7         Free
# 155  1.0       0.7         Free
# 156  1.0       0.8         Free
# 157  3.0       0.8  Partly Free
# 158  1.0       0.8         Free
# 159  1.0       0.8         Free
# 160  1.5       0.9         Free
# 161  1.0       0.9         Free
# 162  5.5       0.9     Not Free
# 163  2.5       0.9         Free
# 164  1.0       1.0         Free
# 165  1.5       1.1         Free
# 166  1.0       1.1         Free
# 167  1.0       1.1         Free
# 168  3.5       1.1  Partly Free
# 169  1.0       1.2         Free
# 170  1.0       1.2         Free
# 171  1.0       1.2         Free
# 172  1.0       1.3         Free
# 173  1.0       1.3         Free
# 174  1.0       1.4         Free
# 175  1.0       1.5         Free
# 176  1.0       1.5         Free
# 177  3.5       1.6  Partly Free
# 178  1.0       1.6         Free
# 179  1.0       1.6         Free
# 180  1.0       1.8         Free
# 181  1.0       1.8         Free
# 182  1.0       1.9         Free
# 183  1.0       2.0         Free
# 184  1.0       2.0         Free
# 185  1.0       2.0         Free
# 186  1.0       2.0         Free
# 187  1.0       2.0         Free
# 188  4.0       2.1  Partly Free
# 189  1.0       2.1         Free
# 190  1.0       2.2         Free
# 191  1.0       2.2         Free
# 192  1.0       2.2         Free
# 193  1.0       2.3         Free
# 194  1.0       2.3         Free

# %%
df_13_dop.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Задание 8
#
# Сгруппировать строки в датафрейме в соответствии со значениями столбца `fh_status`, полученного в предыдущем задании и вывести минимальное, среднее и максимальное значение показателя *Political Stability and Lack of Violence* по каждой группе.

# %%
df_13_dop.groupby('fh_status')

# %%
df_8min = df_13_dop.groupby('fh_status').agg('min')

# %%
df_8min.loc[:,'ps']
# Out:
# fh_status
# Free          -0.99
# Not Free      -2.91
# Partly Free   -2.47
# Name: ps, dtype: float64

# %%
df_8max = df_13_dop.groupby('fh_status').agg('max')

# %%
df_8max.loc[:,'ps']
# Out:
# fh_status
# Free           1.49
# Not Free       1.26
# Partly Free    1.53
# Name: ps, dtype: float64

# %%
df_8mean = df_13_dop.groupby('fh_status').agg('mean')

# %%
df_8mean.loc[:,'ps']
# Out:
# fh_status
# Free           0.619059
# Not Free      -0.875800
# Partly Free   -0.424000
# Name: ps, dtype: float64

# %% [markdown]
# ### Задание 9
#
# Сгруппировать строки в датафрейме в соответствии со значениями столбца `fh_status` и записать строки, относящиеся к разным группам, в отдельные csv-файлы.

# %%
df_13_free = df_13_dop[df_13_dop['fh_status'] == 'Free']
df_13_free.to_csv('df_13_free.csv', index=False, header=None)
df_13_free.head(7)
# Out:
#         country  year    va    ps    ge    rq    rl    cc   fh  cc_round  \
# 70  El Salvador  2016  0.28 -0.06 -0.28  0.09 -0.71 -0.57  2.5      -0.6
# 75     Mongolia  2016  0.45  0.82 -0.11 -0.08 -0.22 -0.50  1.5      -0.5
# 76       Panama  2016  0.53  0.43  0.19  0.36  0.03 -0.49  2.0      -0.5
# 77        Benin  2016  0.50  0.05 -0.57 -0.53 -0.65 -0.48  2.0      -0.5
# 79        Nauru  2016  0.52  0.55 -0.69 -0.38 -0.80 -0.47  2.0      -0.5
# 80        Palau  2016  1.23  0.93 -0.41 -0.18  0.32 -0.47  1.0      -0.5
# 83       Brazil  2016  0.47 -0.45 -0.18 -0.21 -0.08 -0.44  2.0      -0.4
#
#    fh_status
# 70      Free
# 75      Free
# 76      Free
# 77      Free
# 79      Free
# 80      Free
# 83      Free

# %%
df_13_not_free = df_13_dop[df_13_dop['fh_status'] == 'Not Free']
df_13_not_free.to_csv('df_13_not_free.csv', index=False, header=None)
df_13_not_free.head(7)
# Out:
#                 country  year    va    ps    ge    rq    rl    cc   fh  \
# 1     Equatorial Guinea  2016 -1.93 -0.19 -1.41 -1.38 -1.44 -1.81  7.0
# 2               Somalia  2016 -1.83 -2.33 -2.18 -2.27 -2.37 -1.69  7.0
# 3           Yemen, Rep.  2016 -1.65 -2.79 -1.82 -1.48 -1.60 -1.67  6.5
# 4                 Sudan  2016 -1.80 -2.38 -1.41 -1.49 -1.26 -1.61  7.0
# 5           South Sudan  2016 -1.67 -2.42 -2.26 -1.86 -1.69 -1.58  6.5
# 6  Syrian Arab Republic  2016 -1.96 -2.91 -1.82 -1.67 -2.01 -1.57  7.0
# 7                 Libya  2016 -1.37 -2.21 -1.89 -2.27 -1.87 -1.57  6.0
#
#    cc_round fh_status
# 1      -1.8  Not Free
# 2      -1.7  Not Free
# 3      -1.7  Not Free
# 4      -1.6  Not Free
# 5      -1.6  Not Free
# 6      -1.6  Not Free
# 7      -1.6  Not Free

# %%
df_13_partly_free = df_13_dop[df_13_dop['fh_status'] == 'Partly Free']
df_13_partly_free.to_csv('df_13_partly_free.csv', index=False, header=None)
df_13_partly_free.head(7)
# Out:
#             country  year    va    ps    ge    rq    rl    cc   fh  cc_round  \
# 9     Guinea-Bissau  2016 -0.70 -0.50 -1.64 -1.24 -1.49 -1.56  5.0      -1.6
# 15    Venezuela, RB  2016 -1.13 -1.03 -1.29 -2.00 -2.18 -1.39  5.0      -1.4
# 16            Haiti  2016 -0.73 -0.67 -2.06 -1.24 -1.00 -1.35  5.0      -1.4
# 20         Zimbabwe  2016 -1.11 -0.61 -1.16 -1.72 -1.32 -1.28  5.0      -1.3
# 26  Kyrgyz Republic  2016 -0.49 -0.66 -0.90 -0.35 -1.10 -1.08  5.0      -1.1
# 29          Nigeria  2016 -0.30 -1.85 -1.09 -0.92 -1.05 -1.04  4.5      -1.0
# 30          Lebanon  2016 -0.52 -1.56 -0.53 -0.34 -0.86 -0.97  4.5      -1.0
#
#       fh_status
# 9   Partly Free
# 15  Partly Free
# 16  Partly Free
# 20  Partly Free
# 26  Partly Free
# 29  Partly Free
# 30  Partly Free

# %%
len(df_13_dop)
# Out:
# 195

# %%
df_13_dop.index = list(range(1,196))

# %%
df_13_dop.head(5)
# Out:
#              country  year    va    ps    ge    rq    rl    cc   fh  cc_round  \
# 1  Equatorial Guinea  2016 -1.93 -0.19 -1.41 -1.38 -1.44 -1.81  7.0      -1.8
# 2            Somalia  2016 -1.83 -2.33 -2.18 -2.27 -2.37 -1.69  7.0      -1.7
# 3        Yemen, Rep.  2016 -1.65 -2.79 -1.82 -1.48 -1.60 -1.67  6.5      -1.7
# 4              Sudan  2016 -1.80 -2.38 -1.41 -1.49 -1.26 -1.61  7.0      -1.6
# 5        South Sudan  2016 -1.67 -2.42 -2.26 -1.86 -1.69 -1.58  6.5      -1.6
#
#   fh_status
# 1  Not Free
# 2  Not Free
# 3  Not Free
# 4  Not Free
# 5  Not Free

# %% [markdown]
# ### Задание 10
#
# Создайте (любым способом) маленький датафрейм, состоящий из двух столбцов:
#
# * `fh_type`: тип страны;
# * `count`: число стран данного типа.
#
#     Постройте, используя полученный датафрейм, столбиковую диаграмму (*barplot*), опираясь на [эту](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html) документацию. Чтобы увидеть график явно, прямо в текущем ноутбуке, допишите в начале ячейки с кодом для графика следующую строку:
#
#         %matplotlib inline
#
# **Подсказка:** число наблюдений — это функция `count`, её можно использовать наравне с `min`, `mean` и прочими.

# %%
my_list =[
    ['China',24273],
    ['USA',20937],
    ['India',8907],
    ['Germany',4470],
    ['Russia',4133],
    ['Indonesia',3302],
    ['Brasilia', 3154],
    ['France', 3115],
    ['United Kingdom', 3019],
    ['Turkey', 2372],
    
]

# %%
df10 = pd.DataFrame(my_list, columns = ['Country','GDP'])

# %%
df10
# Out:
#           Country    GDP
# 0           China  24273
# 1             USA  20937
# 2           India   8907
# 3         Germany   4470
# 4          Russia   4133
# 5       Indonesia   3302
# 6        Brasilia   3154
# 7          France   3115
# 8  United Kingdom   3019
# 9          Turkey   2372

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
import csv

# %%
df10['Country']
# Out:
# 0             China
# 1               USA
# 2             India
# 3           Germany
# 4            Russia
# 5         Indonesia
# 6          Brasilia
# 7            France
# 8    United Kingdom
# 9            Turkey
# Name: Country, dtype: object

# %%
df10['GDP']
# Out:
# 0    24273
# 1    20937
# 2     8907
# 3     4470
# 4     4133
# 5     3302
# 6     3154
# 7     3115
# 8     3019
# 9     2372
# Name: GDP, dtype: int64

# %%
df10.plot()

# %%
df10['Country'].tolist()
# Out:
# ['China',
#  'USA',
#  'India',
#  'Germany',
#  'Russia',
#  'Indonesia',
#  'Brasilia',
#  'France',
#  'United Kingdom',
#  'Turkey']

# %%
df10['GDP'].tolist()
# Out:
# [24273, 20937, 8907, 4470, 4133, 3302, 3154, 3115, 3019, 2372]

# %%
df10.plot.bar(x = df10['Country'].tolist(), y = df10['GDP'].tolist()) # error

# %%
df10.plot.bar(x='Country', y='GDP', rot=0)
